# %% [markdown]
# # Installing Packages

# %%
# !pip install data-cleaning
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the 'c:\users\mural\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Importing Package

# %%
# data-cleaning package
from datacleaning import DataCleaning

# %% [markdown]
# # Using Default Parameters

# %%
from datacleaning import DataCleaning
import pandas as pd
dp = DataCleaning(file_upload='datasets/cancerdata.csv')
cleaned_df = dp.start_cleaning()
# Out:
# c:\users\mural\appdata\local\programs\python\python37\lib\site-packages\missingpy\missforest.py:528: UserWarning: No missing value located; returning original dataset.
#   warnings.warn("No missing value located; returning original "

# %% [markdown]
# ## Displaying Cleaned DataFrame as cleaned_df

# %%
display(cleaned_df)
# Out:
#             ID  Clump Thickness Uniformity of Cell Size  \
# 0    1241035.0              7.0                       8
# 1    1107684.0              6.0                      10
# 2     691628.0              8.0                       6
# 3    1226612.0              7.0                       5
# 4    1142706.0              5.0                      10
# ..         ...              ...                     ...
# 736   752904.0             10.0                       1
# 737  1296025.0              4.0                       1
# 738   160296.0              5.0                       8
# 739  1016277.0              6.0                       8
# 740   492268.0             10.0                       4
#
#     Uniformity of Cell Shape Marginal Adhesion Single Epithelial Cell Size  \
# 0                          3                 7                           4
# 1                          5                 5                           4
# ...
